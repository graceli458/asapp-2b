# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../evaluation/evaluation_csv_v1.csv")

# %%
df["length"] = df["true_agent_response"].str.len()

# %%
df.rename(columns={ df.columns[0]: "index" }, inplace = True)

# %%
sns.displot(df, y="length", x="index")

# %%
sns.barplot(df, y="length", x="index")
# Out:
# <Axes: xlabel='index', ylabel='length'>
